# %%
def get_song_duration_per_minute(total_duration, number_of_songs):
    try:
        average_duration = total_duration / number_of_songs
        print("Average song duration:", average_duration, "minutes")
    except ZeroDivisionError:
        print("Error: The number of songs cannot be zero.")
    finally:
        print("Spotify duration calculation completed.")


# Example 1
get_song_duration_per_minute(180, 10)

# Example 2: zero songs
get_song_duration_per_minute(180, 0)
# Out:
# Average song duration: 18.0 minutes
# Spotify duration calculation completed.
# Error: The number of songs cannot be zero.
# Spotify duration calculation completed.

# %%
try:
    total_cart_amount = float(input("Enter total cart amount: ₹"))
    item_count = int(input("Enter number of items: "))

    price_per_item = total_cart_amount / item_count

    print("Price per item: ₹", round(price_per_item, 2))

except ZeroDivisionError:
    print("Error: Item count cannot be zero. Please enter at least 1 item.")
# Out:
# Price per item: ₹ 88.89

# %%
class NoOffersApplied(Exception):
    pass


def calculate_cashback_per_offer():
    try:
        total_spend = float(input("Enter total spend: ₹"))
        offers_applied = int(input("Enter number of offers applied: "))

        if offers_applied == 0:
            raise NoOffersApplied("No offers were applied. Cashback cannot be calculated.")

        average_cashback = total_spend / offers_applied

        print("Average cashback per offer: ₹", round(average_cashback, 2))

    except NoOffersApplied as e:
        print("Custom Error:", e)


calculate_cashback_per_offer()
# Out:
# Average cashback per offer: ₹ 750.0

# %%
def calculate_average_rating(total_rating, num_reviews):
    try:
        return total_rating / num_reviews

    except ZeroDivisionError:
        print("Error: Number of reviews cannot be zero.")
        return None

    finally:
        print("Thank you for using the calculator")


result = calculate_average_rating(500, 0)

if result is not None:
    print("Average rating:", result)
# Out:
# Error: Number of reviews cannot be zero.
# Thank you for using the calculator

# %%
result = calculate_average_rating(500, 100)

if result is not None:
    print("Average rating:", result)
# Out:
# Thank you for using the calculator
# Average rating: 5.0

# %%
def safe_divide_for_zomato(bill_amount, number_of_people):
    try:
        amount_per_person = bill_amount / number_of_people

    except ZeroDivisionError:
        print("Error: Number of people cannot be zero.")

    else:
        print("Amount per person: ₹", round(amount_per_person, 2))

    finally:
        print("Split calculation done")


# Example 1
safe_divide_for_zomato(2000, 4)

print()

# Example 2: division by zero
safe_divide_for_zomato(2000, 0)
# Out:
# Amount per person: ₹ 500.0
# Split calculation done
#
# Error: Number of people cannot be zero.
# Split calculation done
